# %%
import pandas as pd

ufo = pd.read_table('http://bit.ly/uforeports', sep=',')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
print(ufo.columns)
ufo.drop(['City', 'Colors Reported'], axis=1, inplace=True)
ufo.head()
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')
#   Shape Reported State             Time
# 0       TRIANGLE    NY   6/1/1930 22:00
# 1          OTHER    NJ  6/30/1930 20:00
# 2           OVAL    CO  2/15/1931 14:00
# 3           DISK    KS   6/1/1931 13:00
# 4          LIGHT    NY  4/18/1933 19:00

# %%
ufo = pd.read_table('http://bit.ly/uforeports', sep=',')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.State.sort_values(ascending = False).head()
# Out:
# 1461    WY
# 1442    WY
# 2437    WY
# 5065    WY
# 1985    WY
# Name: State, dtype: object

# %%
ufo.sort_values('City').head(25)
# Out:
#                       City Colors Reported Shape Reported State  \
# 1761             Abbeville             NaN           DISK    SC
# 4553              Aberdeen             NaN       CYLINDER    WA
# 16167             Aberdeen             NaN        VARIOUS    OH
# 14703             Aberdeen             NaN       TRIANGLE    WA
# 389               Aberdeen          ORANGE         CIRCLE    SD
# 12294             Aberdeen             NaN       FIREBALL    WA
# 17809             Aberdeen           GREEN       FIREBALL    WA
# 9404              Aberdeen             NaN           DISK    MD
# 2297              Aberdeen             NaN       TRIANGLE    MD
# 8357               Abilene             NaN         SPHERE    TX
# 3                  Abilene             NaN           DISK    KS
# 10883              Abilene             NaN            NaN    TX
# 6654               Abilene             NaN       TRIANGLE    TX
# 8783               Abilene             NaN            NaN    KS
# ...

# %%
ufo.sort_values('Shape Reported').head(25)
# Out:
#                  City Colors Reported Shape Reported State              Time
# 17522        Maunaloa             RED        CHEVRON    HI   9/25/2000 20:12
# 12806       Manitowoc             NaN        CHEVRON    WI  12/23/1998 22:35
# 12810     Kansas City             NaN        CHEVRON    MO  12/25/1998 13:30
# 15927       Pine Hill             NaN        CHEVRON    NJ   2/17/2000 21:30
# 8257       Long Beach             NaN        CHEVRON    CA   6/15/1995 20:30
# 4942   Goldens Bridge             NaN        CHEVRON    VA   7/20/1983 22:30
# 4958    Bedford Hills             NaN        CHEVRON    NY   8/15/1983 21:05
# 14974       San Diego             NaN        CHEVRON    CA  10/30/1999 19:25
# 8098         Santa Fe             NaN        CHEVRON    TX   5/12/1995 20:00
# 8068      White Sands             NaN        CHEVRON    NM    5/1/1995 12:00
# 14322           Brier            BLUE        CHEVRON    WA   8/27/1999 22:30
# ...

# %%
ufo.sort_values('Colors Reported').head(1000)
# Out:
#                       City Colors Reported Shape Reported State  \
# 12288           Bettendorf            BLUE          LIGHT    IA
# 12178  San Fernando Valley            BLUE          OTHER    CA
# 7808             Lyndhurst            BLUE       TRIANGLE    OH
# 4038                Dallas            BLUE          LIGHT    TX
# 15699              Atlanta            BLUE         SPHERE    GA
# ...                    ...             ...            ...   ...
# 12210              Castaic      GREEN BLUE          CIGAR    CA
# 7704         McKinleyville      GREEN BLUE            NaN    CA
# 11560                Davie      GREEN BLUE          FLASH    FL
# 6730         New York City      GREEN BLUE       FIREBALL    NY
# 11844            Muscatine      GREEN BLUE           OVAL    IA
#
#                   Time
# 12288  10/2/1998 19:55
# 12178   9/23/1998 0:00
# 7808   2/16/1995 21:25
# 4038     4/4/1979 6:00
# 15699  1/11/2000 22:00
# ...                ...
# 12210  9/23/1998 22:45
# ...

# %%
ufo.sort_values(['Shape Reported','City']).head(25)
# Out:
#                     City Colors Reported Shape Reported State  \
# 15285            Alameda             NaN        CHEVRON    CA
# 3577         Albuquerque             NaN        CHEVRON    NM
# 5477         Albuquerque             NaN        CHEVRON    NM
# 11287         Alexandria             NaN        CHEVRON    VA
# 2225           Allentown             NaN        CHEVRON    PA
# 10871           Alvarado             NaN        CHEVRON    TX
# 12456           Amarillo          YELLOW        CHEVRON    TX
# 6300           Arlington             NaN        CHEVRON    VA
# 3593              Aurora             NaN        CHEVRON    CO
# 5342              Austin             NaN        CHEVRON    TX
# 13076             Austin             NaN        CHEVRON    TX
# 12404               Avon             NaN        CHEVRON    NC
# 10290          Baltimore             NaN        CHEVRON    MD
# 5911       Basking Ridge             NaN        CHEVRON    NJ
# ...
